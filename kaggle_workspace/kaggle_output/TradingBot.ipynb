# %% [markdown]
# # Trading AI Agent
# This notebook runs the Deep Reinforcement Learning Trading Agent.

# %%
# 1. Install Dependencies
# !pip install gymnasium stable-baselines3[extra] pandas pandas-ta matplotlib shimmy

# %%
# 2. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 3. Change Directory to Workspace
import os
# UPDATE THIS PATH if you uploaded it somewhere else
os.chdir('/content/drive/MyDrive/colab_workspace') 
print("Current Working Directory:", os.getcwd())
# !ls

# %%
# 4. Train the Agent
# Note: Ensure 'dataset' folder is present in this directory
# !python train.py

# %%
# 5. Backtest the Agent
# !python backtest.py
